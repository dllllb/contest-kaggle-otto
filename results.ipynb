# %%
import pandas as pd
stats = pd.read_json('results.json').sort_values('score-mean')
stats.T[stats.nunique() > 1]
# Out:
#                      2        6        5        4        3           0  \
# batch_size         256      512      512      512      512         NaN
# calibration      False    False    False    False    False       False
# decay            0.001    0.001    1e-05   0.0001   0.0001         NaN
# epochs               3        6        6        6        3         NaN
# est              keras    keras    keras    keras    keras         xgb
# exec-time-sec  32.3524  59.9256  56.2105  55.2981  29.8098     772.512
# lr                0.01    0.001    0.001    0.001    0.001         NaN
# score-mean    -11.8952 -9.89438 -8.92768 -8.77878 -7.61414   -0.482933
# score-std      4.40174  3.96125  3.43006  3.52162  2.73911  0.00535488
#
#                         1
# batch_size            NaN
# calibration          True
# decay                 NaN
# epochs                NaN
# est                   xgb
# exec-time-sec     3183.97
# lr                    NaN
# score-mean      -0.473761
# ...
